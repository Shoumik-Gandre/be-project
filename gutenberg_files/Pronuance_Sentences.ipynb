# %%
import pandas as pd

# %%
df = pd.read_csv('gaja_sentences.csv')
df.head()
# Out:
#                                           Sentences1  \
# 0                      [ Emma by Jane Austen 1816 ]
# 1                                          VOLUME I
# 2                                         CHAPTER I
# 3  Emma Woodhouse handsome clever and rich with a...
# 4  She was the youngest of the two daughters of a...
#
#                                       Setences1_cont Unnamed: 2 Unnamed: 3  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   and had lived nearly twenty - one years in th...        NaN        NaN
# 4   and had in consequence of her sister ' s marr...        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['Sentences1', 'Setences1_cont', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
import numpy as np
df[df['Unnamed: 8']!=np.nan]
# Out:
#                                              Sentences1  \
# 0                         [ Emma by Jane Austen 1816 ]
# 1                                             VOLUME I
# 2                                            CHAPTER I
# 3     Emma Woodhouse handsome clever and rich with a...
# 4     She was the youngest of the two daughters of a...
# ...                                                 ...
# 5191  While either of them protected him and his Har...
# 5192  The result of this distress was that with a mu...
# 5193  The wedding was very much like other weddings ...
# 5194  -- But in spite of these deficiencies the wish...
# 5195                                             FINIS
#
#                                          Setences1_cont  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3      and had lived nearly twenty - one years in th...
# ...

# %%
df.to_excel('final.xls')
# Out:
# <ipython-input-6-1e382525fd3e>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('final.xls')

# %%
df.fillna("$", inplace=True)
df
# Out:
#                                              Sentences1  \
# 0                         [ Emma by Jane Austen 1816 ]
# 1                                             VOLUME I
# 2                                            CHAPTER I
# 3     Emma Woodhouse handsome clever and rich with a...
# 4     She was the youngest of the two daughters of a...
# ...                                                 ...
# 5191  While either of them protected him and his Har...
# 5192  The result of this distress was that with a mu...
# 5193  The wedding was very much like other weddings ...
# 5194  -- But in spite of these deficiencies the wish...
# 5195                                             FINIS
#
#                                          Setences1_cont  \
# 0                                                     $
# 1                                                     $
# 2                                                     $
# 3      and had lived nearly twenty - one years in th...
# ...

# %%
df['sentence']=df['Sentences1']+df['Setences1_cont']+df['Unnamed: 2']+df['Unnamed: 3']+df['Unnamed: 4']+df['Unnamed: 5']+df['Unnamed: 6']+df['Unnamed: 7']+df['Unnamed: 8']

# %%
df['sentence']
# Out:
# 0                   [ Emma by Jane Austen 1816 ] $$$$$$$$
# 1                                       VOLUME I $$$$$$$$
# 2                                      CHAPTER I $$$$$$$$
# 3       Emma Woodhouse handsome clever and rich with a...
# 4       She was the youngest of the two daughters of a...
#                               ...
# 5191    While either of them protected him and his Har...
# 5192    The result of this distress was that with a mu...
# 5193    The wedding was very much like other weddings ...
# 5194    -- But in spite of these deficiencies the wish...
# 5195                                       FINIS $$$$$$$$
# Name: sentence, Length: 5196, dtype: object

# %%
df['sentence'] = df['sentence'].str.replace('[#,@,&,$]', '')
df['sentence'] = df['sentence'].str.replace('[', '')
df['sentence'] = df['sentence'].str.replace(']', '')
df['sentence']
# Out:
# <ipython-input-10-cdbaa9f7fdf6>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentence'] = df['sentence'].str.replace('[#,@,&,$]', '')
# <ipython-input-10-cdbaa9f7fdf6>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['sentence'] = df['sentence'].str.replace('[', '')
# <ipython-input-10-cdbaa9f7fdf6>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['sentence'] = df['sentence'].str.replace(']', '')
# 0                              Emma by Jane Austen 1816
# 1                                               VOLUME I
# 2                                              CHAPTER I
# ...

# %%
df.columns
# Out:
# Index(['Sentences1', 'Setences1_cont', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'sentence'],
#       dtype='object')

# %%
df.head()
# Out:
#                                           Sentences1  \
# 0                      [ Emma by Jane Austen 1816 ]
# 1                                          VOLUME I
# 2                                         CHAPTER I
# 3  Emma Woodhouse handsome clever and rich with a...
# 4  She was the youngest of the two daughters of a...
#
#                                       Setences1_cont Unnamed: 2 Unnamed: 3  \
# 0                                                  $          $          $
# 1                                                  $          $          $
# 2                                                  $          $          $
# 3   and had lived nearly twenty - one years in th...          $          $
# 4   and had in consequence of her sister ' s marr...          $          $
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0          $          $          $          $          $
# 1          $          $          $          $          $
# ...

# %%
x=0
df['sentencelength'] = df['sentence'].apply(len)
df
# Out:
#                                              Sentences1  \
# 0                         [ Emma by Jane Austen 1816 ]
# 1                                             VOLUME I
# 2                                            CHAPTER I
# 3     Emma Woodhouse handsome clever and rich with a...
# 4     She was the youngest of the two daughters of a...
# ...                                                 ...
# 5191  While either of them protected him and his Har...
# 5192  The result of this distress was that with a mu...
# 5193  The wedding was very much like other weddings ...
# 5194  -- But in spite of these deficiencies the wish...
# 5195                                             FINIS
#
#                                          Setences1_cont  \
# 0                                                     $
# 1                                                     $
# 2                                                     $
# 3      and had lived nearly twenty - one years in th...
# ...

# %%
df1 = df[['sentence','sentencelength']]
df1['novel']='austen-emma.txt'
df1['sentence_id'] = df1.index
df1
# Out:
# <ipython-input-43-05a4bea3b51c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['novel']='austen-emma.txt'
# <ipython-input-43-05a4bea3b51c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['sentence_id'] = df1.index
#                                                sentence  sentencelength  \
# 0                            Emma by Jane Austen 1816                27
# 1                                             VOLUME I                9
# ...

# %%
df2 = df1[['sentence_id','novel','sentencelength','sentence']]
df2
# Out:
#       sentence_id            novel  sentencelength  \
# 0               0  austen-emma.txt              27
# 1               1  austen-emma.txt               9
# 2               2  austen-emma.txt              10
# 3               3  austen-emma.txt             238
# 4               4  austen-emma.txt             187
# ...           ...              ...             ...
# 5191         5191  austen-emma.txt             157
# 5192         5192  austen-emma.txt             335
# 5193         5193  austen-emma.txt             343
# 5194         5194  austen-emma.txt             211
# 5195         5195  austen-emma.txt               6
#
#                                                sentence
# 0                            Emma by Jane Austen 1816
# 1                                             VOLUME I
# 2                                            CHAPTER I
# 3     Emma Woodhouse handsome clever and rich with a...
# 4     She was the youngest of the two daughters of a...
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect(r'C:\Users\ganes\vosk-api-master\python\example\realtime_pr\db.sqlite3')
c = conn.cursor()

# %%
c.execute('''SELECT * FROM pronuance_words''')
for row in c.fetchall():
    print (row)
# Out:
# (1, 'misunderstandings', 'austen_emma', 4, 17)
# (2, 'companionableness', 'austen_emma', 1, 17)
# (3, 'unceremoniousness', 'austen_emma', 1, 17)
# (4, 'disinterestedness', 'austen_emma', 1, 17)
# (5, 'misunderstanding', 'austen_emma', 1, 16)
# (6, 'incomprehensible', 'austen_emma', 1, 16)
# (7, 'undistinguishing', 'austen_emma', 1, 16)
# (8, 'Disingenuousness', 'austen_emma', 1, 16)
# (9, 'disagreeableness', 'austen_emma', 1, 16)
# (10, 'unseasonableness', 'austen_emma', 1, 16)
# (11, 'unexceptionable', 'austen_emma', 7, 15)
# (12, 'congratulations', 'austen_emma', 7, 15)
# (13, 'recommendations', 'austen_emma', 6, 15)
# (14, 'straightforward', 'austen_emma', 3, 15)
# (15, 'disappointments', 'austen_emma', 2, 15)
# (16, 'accomplishments', 'austen_emma', 1, 15)
# (17, 'acknowledgments', 'austen_emma', 1, 15)
# (18, 'unobjectionable', 'austen_emma', 1, 15)
# (19, 'uninterruptedly', 'austen_emma', 1, 15)
# (20, 'inconsiderately', 'austen_emma', 1, 15)
# ...

# %%
df2.to_sql('pronuance_sentences', conn, if_exists='replace', index = False)
